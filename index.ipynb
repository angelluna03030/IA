# %%
import tensorflow as tf
import numpy as np

# %%
celsius = np.array([-40, 10, 9, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 12, 46, 59, 72, 100], dtype=float)
#

# %%
# Definir la capa de entrada
entrada = tf.keras.Input(shape=[1])

# Definir la capa densa
capa = tf.keras.layers.Dense(units=1)(entrada)

# Crear el modelo secuencial
modelo = tf.keras.Model(inputs=entrada, outputs=capa)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 8
#       5 capa = tf.keras.layers.Dense(units=1)
#       7 # Crear el modelo secuencial
# ----> 8 modelo = tf.keras.Model(inputs=entrada, outputs=capa)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\utils\tracking.py:26, in no_automatic_dependency_tracking.<locals>.wrapper(*args, **kwargs)
#      23 @wraps(fn)
#      24 def wrapper(*args, **kwargs):
#      25     with DotNotTrackScope():
# ---> 26         return fn(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\models\functional.py:126, in Functional.__init__(self, inputs, outputs, name, **kwargs)
#     124 for x in flat_outputs:
#     125     if not isinstance(x, backend.KerasTensor):
# --> 126         raise ValueError(
#     127             "All `outputs` values must be KerasTensors. Received: "
#     128             f"outputs={outputs} including invalid value {x} of "
#     129             f"type {type(x)}"
#     130         )
#     132 if not all(is_input_keras_tensor(t) for t in flat_inputs):
#     133     inputs, outputs = clone_graph_nodes(inputs, outputs)
#
# ValueError: All `outputs` values must be KerasTensors. Received: outputs=<Dense name=dense_5, built=False> including invalid value <Dense name=dense_5, built=False> of type <class 'keras.src.layers.core.dense.Dense'>

# %%
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
print("Comenzado entrenamiento...")

historial = modelo.fit(celsius ,fahrenheit, epochs=1000, verbose=False )
print("ya se entreno el modelo,,,")
# Out:
# Comenzado entrenamiento...
# ya se entreno el modelo,,,

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("# Magnitud de perdida")
plt.plot(historial.history["loss"] )

# %%
entrada = np.array([100.0])
resultado = modelo.predict(entrada)
print("El resultado es " + str(resultado) + " Fahrenheit")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# El resultado es [[200.24638]] Fahrenheit

# %%
# print("Variables internes del modelo")
# print(capa.get_weights())

oculta1 = tf.keras.layers.Dense(units=3, input=[1])
oculta2 = tf.keras.layers.Dense(units=3)
salida = tf.keras.layers.Dense(units=1)
modelo = tf.keras.Sequential([oculta1, oculta2, salida])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 4
#       1 # print("Variables internes del modelo")
#       2 # print(capa.get_weights())
# ----> 4 oculta1 = tf.keras.layers.Dense(units=3, input=[1])
#       5 oculta2 = tf.keras.layers.Dense(units=3)
#       6 salida = tf.keras.layers.Dense(units=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, lora_rank, **kwargs)
#      72 def __init__(
#      73     self,
#      74     units,
#    (...)
#      85     **kwargs,
#      86 ):
# ---> 87     super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#      88     self.units = units
#      89     self.activation = activations.get(activation)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\layer.py:287, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     285     self._input_shape_arg = input_shape_arg
#     286 if kwargs:
# --> 287     raise ValueError(
#     288         "Unrecognized keyword arguments "
#     289         f"passed to {self.__class__.__name__}: {kwargs}"
#     290     )
#     292 self._path = None  # Will be determined in `build_wrapper`
#     293 self.built = False
#
# ValueError: Unrecognized keyword arguments passed to Dense: {'input': [1]}
